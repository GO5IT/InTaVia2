# %%
import pandas as pd

#pd.set_option('precision', 2)

df_at = pd.read_csv('PersonURIs_CSV/APIS_wikidataURIs.csv', names=('wikidataURI', 'label'), skiprows=1)
#df_at
df_nl = pd.read_csv('PersonURIs_CSV/biographynet_wikidataURIs.csv', names=('wikidataURI', 'label'), skiprows=1)
#df_nl
df_fi = pd.read_csv('PersonURIs_CSV/sampo_wikidataURIs.csv', names=('wikidataURI', 'label'), skiprows=1)
#df_fi
df_si = pd.read_csv('PersonURIs_CSV/SBI_wikidataURIs.csv', names=('wikidataURI', 'label'), skiprows=1)
df_si

# #print(df.compare(df_nl))
#merge_at_nl = pd.merge(df_at, df_nl, how="outer", sort=True, indicator=True)
merge_at_nl = pd.merge(df_at, df_nl, how="outer", sort=True)
#merge_at_nl
#merge_at_nl_fi = pd.merge(merge_at_nl, df_fi, how="outer", sort=True, indicator=True)
merge_at_nl_fi = pd.merge(merge_at_nl, df_fi, how="outer", sort=True)
#merge_at_nl_fi
#merge_at_nl_fi_si = pd.merge(merge_at_nl_fi, df_si, how="outer",sort=True, indicator=True)
merge_at_nl_fi_si = pd.merge(merge_at_nl_fi, df_si, how="outer",sort=True, indicator=True)
merge_at_nl_fi_si

# Saving as CSV file
#df_csv = merge_at_nl_fi_si.to_csv('InTaVia/PersonURIs_CSV/merge_at_nl_fi_si.csv')
# Out:
#                                     wikidataURI  \
# 0       http://www.wikidata.org/entity/Q1002064
# 1        http://www.wikidata.org/entity/Q101437
# 2       http://www.wikidata.org/entity/Q1020106
# 3       http://www.wikidata.org/entity/Q1020553
# 4        http://www.wikidata.org/entity/Q102875
# ...                                         ...
# 64102    http://www.wikidata.org/entity/Q999343
# 64103    http://www.wikidata.org/entity/Q999539
# 64104    http://www.wikidata.org/entity/Q999550
# 64105  http://www.wikidata.org/entity/Q99976638
# 64106    http://www.wikidata.org/entity/Q999920
#
#                                                    label      _merge
# 0                                         Fliszár, Janoš  right_only
# 1                                                    Pij  right_only
# 2                                          Tomažič, Pino  right_only
# 3                                         Küzmič, Mikloš  right_only
# ...
