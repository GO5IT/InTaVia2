# %% [markdown]
# # Download InTaVia Wikidata CH object metadata

# %%
# %pip install SPARQLWrapper
# %pip install pandas
# %pip install numpy
# %pip install fsspec
# %pip install rdfpandas

# %%
import sys
import os
from SPARQLWrapper import SPARQLWrapper, JSON, XML, TURTLE, N3, RDF, RDFXML, CSV, TSV, JSONLD, DIGEST
import pandas as pd
import time
from random import randint
import numpy as np
import requests
from rdflib import Graph
import urllib
import fsspec
from rdfpandas.graph import to_graph, to_dataframe
from rdflib import Graph, URIRef, Literal, BNode, Namespace
from rdflib.namespace import NamespaceManager,CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, VOID, XMLNS, XSD

# %%
# Mount Google Drive
from google.colab import drive, files
drive.mount('/content/drive')

# Specify file location (Google Colab and local)
filelocation_google = '/content/drive/MyDrive/Colab Notebooks/InTaVia/Public/'
# Out:
# Mounted at /content/drive

# %%
sparql = SPARQLWrapper('https://query.wikidata.org/sparql')
# Define Prefix for SPARQL query
prefix = """
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX schema: <http://schema.org/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX dbr: <http://dbpedia.org/resource/>
    PREFIX dbp: <http://dbpedia.org/property/>
    PREFIX dbc: <http://dbpedia.org/resource/Category:>
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbt: <http://dbpedia.org/resource/Template:>
    PREFIX dbyago: <http://dbpedia.org/class/yago/>
    PREFIX dct: <http://purl.org/dc/terms/>
    PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX gnd: <http://d-nb.info/gnd/>
    PREFIX gold: <http://purl.org/linguistics/gold/>
    PREFIX prov: <http://www.w3.org/ns/prov#>
    PREFIX umbelrc: <http://umbel.org/umbel/rc/>
    PREFIX viaf: <http://viaf.org/viaf/>
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdata: <http://www.wikidata.org/wiki/Special:EntityData/>
    PREFIX wdno: <http://www.wikidata.org/prop/novalue/>
    PREFIX wdref: <http://www.wikidata.org/reference/>
    PREFIX wds: <http://www.wikidata.org/entity/statement/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX wdtn: <http://www.wikidata.org/prop/direct-normalized/>
    PREFIX wdv: <http://www.wikidata.org/value/>
    PREFIX wikibase: <http://wikiba.se/ontology#>
    PREFIX eventKG-s: <http://eventKG.l3s.uni-hannover.de/schema/>
    PREFIX eventKG-e: <http://eventKG.l3s.uni-hannover.de/resource/>
"""

# %% [markdown]
# ## 1. SPARQL to create the Wikidata object list out of Wikidata persons found in InTaVia data (merge_at_nl_fi.csv)

# %% [markdown]
# ### Count the number of Wikidata objects

# %%
def wikidata_object_list():
  endpoint_url = 'https://query.wikidata.org/sparql'
  query_content=f"""
    SELECT 
      (count(distinct ?item) AS ?ItemCount)
      (count(distinct ?creator) AS ?CreatorCount)
    WHERE
    {{
      # ?item wdt:P1647*/wdt:P170 ?creator .
      #?item wdt:P31 ?itemtype .
      #?item wdt:P1476 ?title .
      #?item wdt:P571 ?inceptiondate .
      #SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". }}
    }}
  """
  query = prefix + query_content
  sparql = SPARQLWrapper(endpoint_url)
  sparql.setQuery(query)
  sparql.setReturnFormat(JSON)
  results = sparql.query().convert()
  #print(results)
  for result in results["results"]["bindings"]:
    ItemCount = result["ItemCount"]["value"]
    CreatorCount = result["CreatorCount"]["value"]
  print('Number of Items: ' + ItemCount)
  print('Number of Creators: ' + CreatorCount)
wikidata_object_list()
# Out:
# {'head': {'vars': ['ItemCount', 'CreatorCount']}, 'results': {'bindings': [{'ItemCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '961191'}, 'CreatorCount': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '208437'}}]}}
# Number of Items: 961191
# Number of Creators: 208437

# %% [markdown]
# ### Define a function (with testing URIs)

# %%
# Testing URIs
#creator_ref = 'http://www.wikidata.org/entity/Q34661'
#creator_ref = 'http://www.wikidata.org/entity/Q736847'
creator_ref = 'http://www.wikidata.org/entity/Q254'
#creator_ref = 'http://www.wikidata.org/entity/Q1000385'
#creator_ref = 'http://www.wikidata.org/entity/Q433652'

def wikidata_object_list(creator_ref):
  endpoint_url = 'https://query.wikidata.org/sparql'
  creator_iriref = '<' + str(creator_ref) + '>'
  query_content=f"""
    SELECT DISTINCT ?item 
    #?title ?itemtype ?itemtypeLabel ?inceptiondate
    WHERE
    {{
      # ?item wdt:P1647*/wdt:P170 {creator_iriref} .
      #?item wdt:P31 ?itemtype .
      #?item wdt:P1476 ?title .
      #?item wdt:P571 ?inceptiondate .
      #SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". }}
    }}
  """
  query = prefix + query_content
  user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
  # TODO adjust user agent; see https://w.wiki/CX6
  sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
  #sparql = SPARQLWrapper(endpoint_url)
  sparql.setQuery(query)
  sparql.setReturnFormat(JSON)
  results = sparql.query().convert()
  print(results)
  # Create an empty dataframe, and append data to the dataframe in each iteration
  df = pd.DataFrame(columns=['item', 'person'])
  #df = pd.DataFrame(columns=['item', 'title', 'itemtype', 'itemtypeLabel', 'inceptiondate'])
  for result in results["results"]["bindings"]:
    item = result["item"]["value"]
    #title = result["title"]["value"]
    #itemtype = result["itemtype"]["value"]
    #itemtypeLabel = result["itemtypeLabel"]["value"]
    #inceptiondate = result["inceptiondate"]["value"]     
    dicts = {'item': item, 'person': creator_ref}
    #dicts = {'item': item, 'title': title, 'itemtype': itemtype, 'itemtypeLabel': itemtypeLabel, 'inceptiondate': inceptiondate}
    df = df.append(dicts, ignore_index=True, sort=False) 
  return df

df = wikidata_object_list(creator_ref)
df
# Out:
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3225216'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q50391437'}}]}}
#                                        item  \
# 0   http://www.wikidata.org/entity/Q3225216
# 1  http://www.wikidata.org/entity/Q50391437
#
#                                 person
# 0  http://www.wikidata.org/entity/Q254
# 1  http://www.wikidata.org/entity/Q254

# %% [markdown]
# ### Batch processing for the function (Caution: long processing time)

# %%
# Get Wikidata URIs from InTaVia data providers
# Testing URIs
#list_Wikidata_URI = ['http://www.wikidata.org/entity/Q34661', 'http://www.wikidata.org/entity/Q736847', 'http://www.wikidata.org/entity/Q1000385', 'http://www.wikidata.org/entity/Q433652']
Wikidata_URI_list_df  = pd.read_csv(filelocation_google + 'PersonURIs_CSV/merge_at_nl_fi.csv')
list_Wikidata_URI = (Wikidata_URI_list_df['wikidataURI']).to_list()
list_Wikidata_URI_0 = list_Wikidata_URI[0:4000]
list_Wikidata_URI_4000 = list_Wikidata_URI[4000:8000]
list_Wikidata_URI_8000 = list_Wikidata_URI[8000:12000]
list_Wikidata_URI_12000 = list_Wikidata_URI[1200:16000]
list_Wikidata_URI_16000 = list_Wikidata_URI[16000:20000]
list_Wikidata_URI_20000 = list_Wikidata_URI[20000:24000]
list_Wikidata_URI_24000 = list_Wikidata_URI[24000:28000]
list_Wikidata_URI_28000 = list_Wikidata_URI[28000:32000]
list_Wikidata_URI_32000 = list_Wikidata_URI[32000:36000]
list_Wikidata_URI_36000 = list_Wikidata_URI[36000:40000]
list_Wikidata_URI_40000 = list_Wikidata_URI[40000:44000]
list_Wikidata_URI_44000 = list_Wikidata_URI[44000:48000]
list_Wikidata_URI_48000 = list_Wikidata_URI[48000:52000]
list_Wikidata_URI_52000 = list_Wikidata_URI[52000:56000]
list_Wikidata_URI_56000 = list_Wikidata_URI[56000:56300]
#print(list_Wikidata_URI_0)
#print(list_Wikidata_URI_4000)

# Create an empty dataframe, and append data to the dataframe in each iteration
df = pd.DataFrame(columns=['item', 'person'])
# Iterate over URI list
for item in list_Wikidata_URI:
    print(str(item) + ' is started')
    df_new = wikidata_object_list(item) 
    df = df.append(df_new, ignore_index=True)   
    print(str(item) + ' completed')
    #Time interval for a next query/iteration
    time.sleep(randint(1,3))
df_csv = df.to_csv(filelocation_google + 'WikidataObjectURIlist/URI_list_df_WikidataObject_0.csv')
# Out:
# http://www.wikidata.org/entity/Q1000005 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1000005 completed
# http://www.wikidata.org/entity/Q100035749 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100035749 completed
# http://www.wikidata.org/entity/Q1000385 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1000385 completed
# http://www.wikidata.org/entity/Q1000555 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1000555 completed
# http://www.wikidata.org/entity/Q1000902 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1000902 completed
# http://www.wikidata.org/entity/Q1000935 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1000935 completed
# http://www.wikidata.org/entity/Q1000981 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1000981 completed
# http://www.wikidata.org/entity/Q1001020 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1001020 completed
# http://www.wikidata.org/entity/Q1001469 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1001469 completed
# http://www.wikidata.org/entity/Q1001611 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1001611 completed
# http://www.wikidata.org/entity/Q1002324 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1002324 completed
# http://www.wikidata.org/entity/Q1002332 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1002332 completed
# http://www.wikidata.org/entity/Q100247777 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100247777 completed
# http://www.wikidata.org/entity/Q100249653 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100249653 completed
# http://www.wikidata.org/entity/Q100276 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100276 completed
# http://www.wikidata.org/entity/Q1002773 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1002773 completed
# http://www.wikidata.org/entity/Q100288 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100288 completed
# http://www.wikidata.org/entity/Q1003307 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q51237461'}}]}}
# http://www.wikidata.org/entity/Q1003307 completed
# http://www.wikidata.org/entity/Q100334063 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100334063 completed
# http://www.wikidata.org/entity/Q100353139 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100353139 completed
# http://www.wikidata.org/entity/Q1003629 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1003629 completed
# http://www.wikidata.org/entity/Q1003633 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1003633 completed
# http://www.wikidata.org/entity/Q100376065 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100376065 completed
# http://www.wikidata.org/entity/Q1003947 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1003947 completed
# http://www.wikidata.org/entity/Q1003970 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1003970 completed
# http://www.wikidata.org/entity/Q100400523 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100400523 completed
# http://www.wikidata.org/entity/Q1004050 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1004050 completed
# http://www.wikidata.org/entity/Q100446793 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100446793 completed
# http://www.wikidata.org/entity/Q1004779 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1004779 completed
# http://www.wikidata.org/entity/Q1004812 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1004812 completed
# http://www.wikidata.org/entity/Q100533 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100533 completed
# http://www.wikidata.org/entity/Q100536805 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100536805 completed
# http://www.wikidata.org/entity/Q100600900 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100600900 completed
# http://www.wikidata.org/entity/Q1006395 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1006395 completed
# http://www.wikidata.org/entity/Q100709237 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100709237 completed
# http://www.wikidata.org/entity/Q1007128 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1007128 completed
# http://www.wikidata.org/entity/Q100715305 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100715305 completed
# http://www.wikidata.org/entity/Q100740784 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100740784 completed
# http://www.wikidata.org/entity/Q100748114 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100748114 completed
# http://www.wikidata.org/entity/Q100770607 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100770607 completed
# http://www.wikidata.org/entity/Q100775950 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100775950 completed
# http://www.wikidata.org/entity/Q100780109 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100780109 completed
# http://www.wikidata.org/entity/Q100839163 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100839163 completed
# http://www.wikidata.org/entity/Q100840271 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100840271 completed
# http://www.wikidata.org/entity/Q100865 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100865 completed
# http://www.wikidata.org/entity/Q100886 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100886 completed
# http://www.wikidata.org/entity/Q100886087 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100886087 completed
# http://www.wikidata.org/entity/Q100887787 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100887787 completed
# http://www.wikidata.org/entity/Q100887851 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100887851 completed
# http://www.wikidata.org/entity/Q100896 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100896 completed
# http://www.wikidata.org/entity/Q100896 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100896 completed
# http://www.wikidata.org/entity/Q1008981 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1008981 completed
# http://www.wikidata.org/entity/Q100901 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100901 completed
# http://www.wikidata.org/entity/Q100910 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21997970'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q66006091'}}]}}
# http://www.wikidata.org/entity/Q100910 completed
# http://www.wikidata.org/entity/Q1009174 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1009174 completed
# http://www.wikidata.org/entity/Q1009176 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1009176 completed
# http://www.wikidata.org/entity/Q100934208 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100934208 completed
# http://www.wikidata.org/entity/Q10093755 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q10093755 completed
# http://www.wikidata.org/entity/Q100938540 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100938540 completed
# http://www.wikidata.org/entity/Q100938606 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100938606 completed
# http://www.wikidata.org/entity/Q100938858 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100938858 completed
# http://www.wikidata.org/entity/Q100939207 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100939207 completed
# http://www.wikidata.org/entity/Q100940214 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100940214 completed
# http://www.wikidata.org/entity/Q100940255 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100940255 completed
# http://www.wikidata.org/entity/Q100940295 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100940295 completed
# http://www.wikidata.org/entity/Q100940351 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100940351 completed
# http://www.wikidata.org/entity/Q100940560 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100940560 completed
# http://www.wikidata.org/entity/Q100940909 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100940909 completed
# http://www.wikidata.org/entity/Q100941343 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100941343 completed
# http://www.wikidata.org/entity/Q1009415 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1009415 completed
# http://www.wikidata.org/entity/Q100996368 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q100996368 completed
# http://www.wikidata.org/entity/Q101007338 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101007338 completed
# http://www.wikidata.org/entity/Q101007739 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101007739 completed
# http://www.wikidata.org/entity/Q101008423 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101008423 completed
# http://www.wikidata.org/entity/Q101011540 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101011540 completed
# http://www.wikidata.org/entity/Q101011540 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101011540 completed
# http://www.wikidata.org/entity/Q1010413 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1010413 completed
# http://www.wikidata.org/entity/Q101044830 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101044830 completed
# http://www.wikidata.org/entity/Q101044987 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101044987 completed
# http://www.wikidata.org/entity/Q101045086 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045086 completed
# http://www.wikidata.org/entity/Q101045312 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045312 completed
# http://www.wikidata.org/entity/Q101045461 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045461 completed
# http://www.wikidata.org/entity/Q101045495 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045495 completed
# http://www.wikidata.org/entity/Q101045634 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045634 completed
# http://www.wikidata.org/entity/Q101045890 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045890 completed
# http://www.wikidata.org/entity/Q101045952 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045952 completed
# http://www.wikidata.org/entity/Q101045967 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101045967 completed
# http://www.wikidata.org/entity/Q101046109 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101046109 completed
# http://www.wikidata.org/entity/Q101046243 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101046243 completed
# http://www.wikidata.org/entity/Q101047654 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101047654 completed
# http://www.wikidata.org/entity/Q101047749 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101047749 completed
# http://www.wikidata.org/entity/Q101047777 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101047777 completed
# http://www.wikidata.org/entity/Q101047823 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101047823 completed
# http://www.wikidata.org/entity/Q101047920 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101047920 completed
# http://www.wikidata.org/entity/Q101048409 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101048409 completed
# http://www.wikidata.org/entity/Q101048758 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101048758 completed
# http://www.wikidata.org/entity/Q101048866 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101048866 completed
# http://www.wikidata.org/entity/Q1010497 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1010497 completed
# http://www.wikidata.org/entity/Q101049995 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101049995 completed
# http://www.wikidata.org/entity/Q101050653 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101050653 completed
# http://www.wikidata.org/entity/Q101050721 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101050721 completed
# http://www.wikidata.org/entity/Q101050764 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101050764 completed
# http://www.wikidata.org/entity/Q101050818 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101050818 completed
# http://www.wikidata.org/entity/Q101051085 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101051085 completed
# http://www.wikidata.org/entity/Q101051248 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101051248 completed
# http://www.wikidata.org/entity/Q101051508 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101051508 completed
# http://www.wikidata.org/entity/Q101051534 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101051534 completed
# http://www.wikidata.org/entity/Q101060469 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101060469 completed
# http://www.wikidata.org/entity/Q101063270 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063270 completed
# http://www.wikidata.org/entity/Q101063550 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063550 completed
# http://www.wikidata.org/entity/Q101063551 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063551 completed
# http://www.wikidata.org/entity/Q101063552 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063552 completed
# http://www.wikidata.org/entity/Q101063554 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063554 completed
# http://www.wikidata.org/entity/Q101063555 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063555 completed
# http://www.wikidata.org/entity/Q101063557 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063557 completed
# http://www.wikidata.org/entity/Q101063558 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063558 completed
# http://www.wikidata.org/entity/Q101063559 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063559 completed
# http://www.wikidata.org/entity/Q101063561 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063561 completed
# http://www.wikidata.org/entity/Q101063562 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063562 completed
# http://www.wikidata.org/entity/Q101063563 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063563 completed
# http://www.wikidata.org/entity/Q101063564 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063564 completed
# http://www.wikidata.org/entity/Q101063565 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063565 completed
# http://www.wikidata.org/entity/Q101063566 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063566 completed
# http://www.wikidata.org/entity/Q101063567 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063567 completed
# http://www.wikidata.org/entity/Q101063568 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063568 completed
# http://www.wikidata.org/entity/Q101063570 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063570 completed
# http://www.wikidata.org/entity/Q101063572 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063572 completed
# http://www.wikidata.org/entity/Q101063573 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063573 completed
# http://www.wikidata.org/entity/Q101063576 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063576 completed
# http://www.wikidata.org/entity/Q101063578 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063578 completed
# http://www.wikidata.org/entity/Q101063579 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063579 completed
# http://www.wikidata.org/entity/Q101063581 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063581 completed
# http://www.wikidata.org/entity/Q101063583 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063583 completed
# http://www.wikidata.org/entity/Q101063584 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063584 completed
# http://www.wikidata.org/entity/Q101063586 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063586 completed
# http://www.wikidata.org/entity/Q101063589 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063589 completed
# http://www.wikidata.org/entity/Q101063667 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063667 completed
# http://www.wikidata.org/entity/Q101063849 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063849 completed
# http://www.wikidata.org/entity/Q101063906 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101063906 completed
# http://www.wikidata.org/entity/Q101064055 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101064055 completed
# http://www.wikidata.org/entity/Q101068122 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101068122 completed
# http://www.wikidata.org/entity/Q101071157 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101071157 completed
# http://www.wikidata.org/entity/Q101076766 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101076766 completed
# http://www.wikidata.org/entity/Q101080636 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101080636 completed
# http://www.wikidata.org/entity/Q101081674 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101081674 completed
# http://www.wikidata.org/entity/Q101087485 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101087485 completed
# http://www.wikidata.org/entity/Q101095764 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101095764 completed
# http://www.wikidata.org/entity/Q101108 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101108 completed
# http://www.wikidata.org/entity/Q101108 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101108 completed
# http://www.wikidata.org/entity/Q101131531 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101131531 completed
# http://www.wikidata.org/entity/Q101139490 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101139490 completed
# http://www.wikidata.org/entity/Q101144537 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101144537 completed
# http://www.wikidata.org/entity/Q101173967 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101173967 completed
# http://www.wikidata.org/entity/Q101192134 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101192134 completed
# http://www.wikidata.org/entity/Q101197215 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101197215 completed
# http://www.wikidata.org/entity/Q101198460 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101198460 completed
# http://www.wikidata.org/entity/Q101204290 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101204290 completed
# http://www.wikidata.org/entity/Q101207391 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101207391 completed
# http://www.wikidata.org/entity/Q101214 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101214 completed
# http://www.wikidata.org/entity/Q101244293 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101244293 completed
# http://www.wikidata.org/entity/Q101247703 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101247703 completed
# http://www.wikidata.org/entity/Q101259366 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101259366 completed
# http://www.wikidata.org/entity/Q101324 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101324 completed
# http://www.wikidata.org/entity/Q101336 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101336 completed
# http://www.wikidata.org/entity/Q101338250 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101338250 completed
# http://www.wikidata.org/entity/Q101350087 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q107483346'}}]}}
# http://www.wikidata.org/entity/Q101350087 completed
# http://www.wikidata.org/entity/Q101423111 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101423111 completed
# http://www.wikidata.org/entity/Q101445662 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101445662 completed
# http://www.wikidata.org/entity/Q101451 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101451 completed
# http://www.wikidata.org/entity/Q101466902 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101466902 completed
# http://www.wikidata.org/entity/Q101515212 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101515212 completed
# http://www.wikidata.org/entity/Q101515670 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101515670 completed
# http://www.wikidata.org/entity/Q101516262 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101516262 completed
# http://www.wikidata.org/entity/Q101525271 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101525271 completed
# http://www.wikidata.org/entity/Q101548348 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101548348 completed
# http://www.wikidata.org/entity/Q101554960 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101554960 completed
# http://www.wikidata.org/entity/Q101555068 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101555068 completed
# http://www.wikidata.org/entity/Q101565463 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27311528'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q61944062'}}]}}
# http://www.wikidata.org/entity/Q101565463 completed
# http://www.wikidata.org/entity/Q101574087 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101574087 completed
# http://www.wikidata.org/entity/Q101579588 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101579588 completed
# http://www.wikidata.org/entity/Q101579736 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101579736 completed
# http://www.wikidata.org/entity/Q101579737 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101579737 completed
# http://www.wikidata.org/entity/Q101579738 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101579738 completed
# http://www.wikidata.org/entity/Q101583487 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101583487 completed
# http://www.wikidata.org/entity/Q101583854 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101583854 completed
# http://www.wikidata.org/entity/Q101584466 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101584466 completed
# http://www.wikidata.org/entity/Q101584470 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101584470 completed
# http://www.wikidata.org/entity/Q101584515 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101584515 completed
# http://www.wikidata.org/entity/Q101626827 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101626827 completed
# http://www.wikidata.org/entity/Q101627968 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101627968 completed
# http://www.wikidata.org/entity/Q101698 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101698 completed
# http://www.wikidata.org/entity/Q101746633 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101746633 completed
# http://www.wikidata.org/entity/Q101757683 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101757683 completed
# http://www.wikidata.org/entity/Q101781718 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101781718 completed
# http://www.wikidata.org/entity/Q101783613 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101783613 completed
# http://www.wikidata.org/entity/Q101785076 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101785076 completed
# http://www.wikidata.org/entity/Q101787301 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101787301 completed
# http://www.wikidata.org/entity/Q101832562 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101832562 completed
# http://www.wikidata.org/entity/Q1019415 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q1019415 completed
# http://www.wikidata.org/entity/Q101942 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101942 completed
# http://www.wikidata.org/entity/Q101952 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101952 completed
# http://www.wikidata.org/entity/Q101985723 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q101985723 completed
# http://www.wikidata.org/entity/Q102016 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102016 completed
# http://www.wikidata.org/entity/Q102022 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102022 completed
# http://www.wikidata.org/entity/Q102036003 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102036003 completed
# http://www.wikidata.org/entity/Q102044115 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102044115 completed
# http://www.wikidata.org/entity/Q102045692 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102045692 completed
# http://www.wikidata.org/entity/Q102047869 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q102079921'}}]}}
# http://www.wikidata.org/entity/Q102047869 completed
# http://www.wikidata.org/entity/Q102047887 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q102080928'}}]}}
# http://www.wikidata.org/entity/Q102047887 completed
# http://www.wikidata.org/entity/Q102047891 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q102081358'}}]}}
# http://www.wikidata.org/entity/Q102047891 completed
# http://www.wikidata.org/entity/Q102047895 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q102081480'}}]}}
# http://www.wikidata.org/entity/Q102047895 completed
# http://www.wikidata.org/entity/Q102066508 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102066508 completed
# http://www.wikidata.org/entity/Q102071 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q200344'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q393843'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q422902'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q589198'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1289624'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2386077'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2503697'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2569920'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2604643'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2608368'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2635348'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2914822'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3209530'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3530285'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3735893'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3744199'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4405481'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q5398661'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6306019'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10672707'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10791871'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11850552'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11860061'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11867838'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11883591'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11888073'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11894175'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11895348'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q16419303'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q16424134'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q18693528'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20787695'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20795333'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q20796696'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q62395583'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q105110642'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q109936735'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q111801836'}}]}}
# http://www.wikidata.org/entity/Q102071 completed
# http://www.wikidata.org/entity/Q102077413 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102077413 completed
# http://www.wikidata.org/entity/Q102077551 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102077551 completed
# http://www.wikidata.org/entity/Q102077710 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102077710 completed
# http://www.wikidata.org/entity/Q102078129 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102078129 completed
# http://www.wikidata.org/entity/Q102089106 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102089106 completed
# http://www.wikidata.org/entity/Q102107922 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102107922 completed
# http://www.wikidata.org/entity/Q102108579 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102108579 completed
# http://www.wikidata.org/entity/Q102111244 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102111244 completed
# http://www.wikidata.org/entity/Q102121 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102121 completed
# http://www.wikidata.org/entity/Q102123717 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102123717 completed
# http://www.wikidata.org/entity/Q102128116 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102128116 completed
# http://www.wikidata.org/entity/Q102128134 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102128134 completed
# http://www.wikidata.org/entity/Q102147581 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102147581 completed
# http://www.wikidata.org/entity/Q102152228 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102152228 completed
# http://www.wikidata.org/entity/Q102156187 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102156187 completed
# http://www.wikidata.org/entity/Q102204 is started
# {'head': {'vars': ['item']}, 'results': {'bindings': []}}
# http://www.wikidata.org/entity/Q102204 completed

# %% [markdown]
# ## 2. HTTP request to fetch the Wikidata object metadata out of the list out of Wikidata object list(URI_list_df_WikidataObject.csv)

# %% [markdown]
# ### Define a function (with testing URIs)

# %%
# Testing URI
wikidataURI = 'http://www.wikidata.org/entity/Q698487'

def fetch_wikidata_metadata(wikidataURI):
  headers = {
    'Accept': 'text/turtle',
    'Content-type': 'text/turtle'
  }
  r = requests.get(wikidataURI, headers=headers)
  try:
    print(r.raise_for_status())
    return(r.text)
  except requests.exceptions.HTTPError as e: 
    print(e)
    return

turtle = fetch_wikidata_metadata(wikidataURI)
print(turtle)

# %% [markdown]
# ### Batch processing for the function (Caution: long processing time)

# %%
URI_list_df  = pd.read_csv(filelocation_google + 'WikidataObjectURIlist/URI_list_df_WikidataObject.csv')
list_item = (URI_list_df['item']).to_list()
list_person = (URI_list_df['person']).to_list()

# Iterate over URI list
i = 0
for item in list_item:
  print('Processing ' + str(item) + ' started')
  turtle_wikidata_object = fetch_wikidata_metadata(item)
  # Check if turtle file was fetched
  if turtle_wikidata_object != None:
    itemid=  item.rsplit('/', 1)[1]
    personid = list_person[i].rsplit('/', 1)[1]
    filename = str(itemid) + '_by_' + str(personid)
    print(filename + ' is fetched')
    # Saving as Turtle (using itemid + personid)
    with open(filelocation_google + 'WikidataObjectTurtle/' + str(filename) + '.ttl', 'w') as f:
      f.write(turtle_wikidata_object)
    files.download(filelocation_google + 'WikidataObjectTurtle/' + str(filename) + '.ttl')
  else:
    pass
    print('HTTP error: No Turtle can be fetched from ' + str(item))
  print('Processing ' + str(item) + ' completed')
  print('-----------------')
  #Time interval for a next query/iteration
  time.sleep(randint(1,3))
  i = i + 1

# %%
while True:pass
